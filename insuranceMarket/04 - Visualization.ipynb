# %%
from __future__ import print_function, division
import pandas as pd
import sklearn
import scipy

from scipy.stats import mode
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.grid_search import GridSearchCV

pd.options.display.max_rows = 11
print("pandas: {}".format(pd.__version__))
print("sklearn: {}".format(sklearn.__version__))
print("scipy: {}".format(scipy.__version__))
# Out:
# pandas: 0.18.1
# sklearn: 0.16.1
# scipy: 0.13.3

# %%
df = pd.read_csv("training.csv")
averageAge = df.custAge.mean()
df.custAge = df.custAge.fillna(averageAge)

## df[col].mode() seems to include NaN as a possible output,
## whereas scipy.stats.mode doesn't.
## We obviously don't want NaN as the mode because that's what we're replacing
schoolingMode = mode(df.schooling)[0][0]
df.schooling = df.schooling.fillna(schoolingMode)

dayMode = mode(df.day_of_week)[0][0]
df.day_of_week = df.day_of_week.fillna(dayMode)

df.profit = df.profit.fillna(0)

df
# Out:
# /usr/local/lib/python2.7/dist-packages/numpy/lib/arraysetops.py:200: FutureWarning: numpy not_equal will not check object identity in the future. The comparison did not return the same result as suggested by the identity (`is`)) and will change.
#   flag = np.concatenate(([True], aux[1:] != aux[:-1]))
#         custAge     profession   marital          schooling  default housing  \
# 0     34.000000         admin.    single  university.degree       no      no
# 1     31.000000       services    single        high.school       no      no
# 2     39.953728         admin.    single        high.school       no      no
# 3     52.000000         admin.  divorced  university.degree  unknown     yes
# 4     39.000000    blue-collar    single  university.degree  unknown     yes
# ...         ...            ...       ...                ...      ...     ...
# 8233  55.000000        retired   married        high.school       no     yes
# 8234  41.000000         admin.  divorced        high.school       no      no
# 8235  32.000000  self-employed    single  university.degree       no      no
# 8236  39.953728      housemaid   married  university.degree       no      no
# 8237  85.000000      housemaid   married  university.degree  unknown     yes
#
#      loan    contact month day_of_week  ...   emp.var.rate  cons.price.idx  \
# 0     yes   cellular   apr         wed  ...           -1.8          93.075
# 1      no   cellular   jul         thu  ...            1.4          93.918
# 2      no  telephone   jun         mon  ...            1.4          94.465
# 3      no   cellular   jul         tue  ...            1.4          93.918
# 4      no   cellular   jul         tue  ...            1.4          93.918
# ...   ...        ...   ...         ...  ...            ...             ...
# 8233   no   cellular   oct         thu  ...           -3.4          92.431
# 8234   no  telephone   jun         mon  ...            1.4          94.465
# 8235   no   cellular   apr         thu  ...           -1.8          93.075
# 8236   no   cellular   jun         tue  ...           -2.9          92.963
# 8237   no   cellular   apr         tue  ...           -1.8          93.749
#
#       cons.conf.idx euribor3m  nr.employed     pmonths  pastEmail  responded  \
# 0             -47.1     1.498       5099.1  999.000000          0         no
# 1             -42.7     4.968       5228.1  999.000000          0         no
# 2             -41.8     4.961       5228.1  999.000000          0         no
# 3             -42.7     4.962       5228.1  999.000000          0         no
# 4             -42.7     4.961       5228.1  999.000000          0         no
# ...             ...       ...          ...         ...        ...        ...
# 8233          -26.9     0.722       5017.5    0.233333          0        yes
# 8234          -41.8     4.960       5228.1  999.000000          0        yes
# 8235          -47.1     1.435       5099.1  999.000000          0        yes
# 8236          -40.8     1.099       5076.2  999.000000          0        yes
# 8237          -34.6     0.642       5008.7  999.000000          1        yes
#
#       profit    id
# 0        0.0     1
# 1        0.0     2
# 2        0.0     3
# 3        0.0     4
# 4        0.0     5
# ...      ...   ...
# 8233   203.0  8234
# 8234   188.0  8235
# 8235   208.0  8236
# 8236   129.0  8237
# 8237    33.0  8238
#
# [8238 rows x 24 columns]

# %%
df.plot(x="custAge", y="profit", kind="scatter")

# %%
bycat = df.pivot_table(index="profession", values="profit", aggfunc=np.mean)
bycat.plot(kind="bar")

# %%
categorical = ["profession", "schooling", "marital", "month", "day_of_week"]
fig, axs = plt.subplots(nrows=len(categorical), figsize=(10, 4*len(categorical)))
for i, col in enumerate(categorical):
    bycat = df.pivot_table(index=col, values="profit", aggfunc=np.mean)
    bycat.plot(kind="bar", ax=axs[i])
    axs[i].set_title(col)
